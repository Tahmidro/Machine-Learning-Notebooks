# %% [markdown]
# <a href="https://colab.research.google.com/github/Tahmidro/Machine-Learning-Notebooks/blob/main/kmeans_implememtation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# %%
df=load_iris(as_frame=True).frame
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# ...

# %%
X=df[["sepal length (cm)","sepal width (cm)"]]

# %%
scaler=StandardScaler()
X=scaler.fit_transform(X)

# %%
kmeans=KMeans(
    n_clusters=3,
    init="k-means++",
    n_init="auto",
    max_iter=400,
    random_state=42
)

# %%
kmeans.fit(X)
# Out:
# KMeans(max_iter=400, n_clusters=3, random_state=42)

# %%
labels=kmeans.labels_
df["clusters"]=labels

# %%
df.sample(10)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 58                 6.6               2.9                4.6               1.3
# 84                 5.4               3.0                4.5               1.5
# 59                 5.2               2.7                3.9               1.4
# 112                6.8               3.0                5.5               2.1
# 144                6.7               3.3                5.7               2.5
# 73                 6.1               2.8                4.7               1.2
# 51                 6.4               3.2                4.5               1.5
# 106                4.9               2.5                4.5               1.7
# 22                 4.6               3.6                1.0               0.2
# 28                 5.2               3.4                1.4               0.2
#
#      target  clusters
# 58        1         0
# 84        1         1
# 59        1         1
# ...

# %%
sns.scatterplot(
    data=df,
    x="sepal length (cm)",
    y="sepal width (cm)",
    hue="clusters",
    palette="deep"
)
plt.xlabel("sepal length (cm)")
plt.ylabel("sepal width (cm)")
plt.title("Clusters of Iris Flowers")
plt.show()
