# %% [markdown]
# <a href="https://colab.research.google.com/github/Tahmidro/Machine-Learning-Notebooks/blob/main/DBSCAN_Implementation_sklearn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans,DBSCAN
from sklearn.datasets import make_moons

# %%
X, y = make_moons(n_samples=300, noise=0.06, random_state=42)
plt.scatter(X[:, 0], X[:, 1])
plt.show()

# %%
scaler=StandardScaler()
X_scaled=scaler.fit_transform(X)

# %%
dbscan=DBSCAN(eps=0.3,min_samples=3)
dbscan.fit(X_scaled)
# Out:
# DBSCAN(eps=0.3, min_samples=3)

# %%
labels=dbscan.labels_

# %%
sns.scatterplot(x=X_scaled[:,0],y=X_scaled[:,1],hue=labels,palette="viridis")
# Out:
# <Axes: >
